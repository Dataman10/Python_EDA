# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (2.3.2)
# Requirement already satisfied: pandas in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hitesh\onedrive\documents\python\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Books_Data_Clean.csv')

# %%
df.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# 1  Intermediate                 4.23              145267  genre fiction
# 2        Novice                 3.31              138669  genre fiction
# 3  Intermediate                 4.04              150898        fiction
# 4  Intermediate                 4.04              198283  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
# 1      12437.5             7462.5        1.99           2
# 2      47795.0            28677.0        8.69           3
# 3      41250.0            24750.0        7.50           3
# 4      37952.5            22771.5        7.99           4
#
#                        Publisher   units sold
# 0        HarperCollins Publishers        7000
# 1        HarperCollins Publishers        6250
# 2  Amazon Digital Services,  Inc.        5500
# 3             Hachette Book Group        5500
# 4         Penguin Group (USA) LLC        4750

# %% [markdown]
# df.describe()

# %%
df = df[df['Publishing Year'] > 1900]

# %%
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                            Harper Lee           eng
# 3                                         David Sedaris         en-US
# 4                                          Laini Taylor           eng
# ...                                                 ...           ...
# 1065                                       John Grisham           eng
# 1066                                    Bryce Courtenay           eng
# 1067                                   Dashiell Hammett           eng
# 1068                                     Kristin Hannah         en-US
# 1069                                          Lee Child           eng
#
#      Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0           Novice                 3.42              155903  genre fiction
# 1     Intermediate                 4.23              145267  genre fiction
# 2           Novice                 3.31              138669  genre fiction
# 3     Intermediate                 4.04              150898        fiction
# 4     Intermediate                 4.04              198283  genre fiction
# ...            ...                  ...                 ...            ...
# 1065  Intermediate                 3.52               37379     nonfiction
# 1066     Excellent                 4.34               57312  genre fiction
# 1067  Intermediate                 3.92               58742  genre fiction
# 1068     Excellent                 4.17               58028  genre fiction
# 1069     Excellent                 4.07               55251  genre fiction
#
#       gross sales  publisher revenue  sale price  sales rank  \
# 0        34160.00          20496.000        4.88           1
# 1        12437.50           7462.500        1.99           2
# 2        47795.00          28677.000        8.69           3
# 3        41250.00          24750.000        7.50           3
# 4        37952.50          22771.500        7.99           4
# ...           ...                ...         ...         ...
# 1065       104.94             62.964        0.99        1268
# 1066       846.94            508.164        7.99        1270
# 1067       846.94            508.164        7.99        1271
# 1068       104.94             62.964        0.99        1272
# 1069       316.94              0.000        2.99        1273
#
#                           Publisher   units sold
# 0           HarperCollins Publishers        7000
# 1           HarperCollins Publishers        6250
# 2     Amazon Digital Services,  Inc.        5500
# 3                Hachette Book Group        5500
# 4            Penguin Group (USA) LLC        4750
# ...                              ...         ...
# 1065  Amazon Digital Services,  Inc.         106
# 1066                Random House LLC         106
# 1067             Hachette Book Group         106
# 1068  Amazon Digital Services,  Inc.         106
# 1069  Amazon Digital Services,  Inc.         106
#
# [1009 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name              21
# Author                  0
# language_code          49
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.dtypes
# Out:
# index                    int64
# Publishing Year        float64
# Book Name               object
# Author                  object
# language_code           object
# Author_Rating           object
# Book_average_rating    float64
# Book_ratings_count       int64
# genre                   object
# gross sales            float64
# publisher revenue      float64
# sale price             float64
# sales rank               int64
# Publisher               object
# units sold               int64
# dtype: object

# %%
df.dropna(subset = 'Book Name' , inplace = True)

# %%
df.head(10)
# Out:
#    index  Publishing Year                                Book Name  \
# 0      0           1975.0                                  Beowulf
# 1      1           1987.0                         Batman: Year One
# 2      2           2015.0                        Go Set a Watchman
# 3      3           2008.0          When You Are Engulfed in Flames
# 4      4           2011.0                 Daughter of Smoke & Bone
# 5      5           2015.0                                Red Queen
# 6      6           2011.0                       The Power of Habit
# 7      7           1994.0  Midnight in the Garden of Good and Evil
# 8      8           2012.0                                 Hopeless
# 9      9           1905.0                        A Little Princess
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
# 5                                   Victoria Aveyard           eng
# 6                                     Charles Duhigg           eng
# 7                                       John Berendt           eng
# 8                                     Colleen Hoover           eng
# 9                Frances Hodgson Burnett, Nancy Bond           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# 1  Intermediate                 4.23              145267  genre fiction
# 2        Novice                 3.31              138669  genre fiction
# 3  Intermediate                 4.04              150898        fiction
# 4  Intermediate                 4.04              198283  genre fiction
# 5  Intermediate                 4.08               83354  genre fiction
# 6  Intermediate                 4.03              155977  genre fiction
# 7  Intermediate                 3.90              167997     nonfiction
# 8  Intermediate                 4.34              189938  genre fiction
# 9  Intermediate                 4.20              199872  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0     34160.00          20496.000        4.88           1
# 1     12437.50           7462.500        1.99           2
# 2     47795.00          28677.000        8.69           3
# 3     41250.00          24750.000        7.50           3
# 4     37952.50          22771.500        7.99           4
# 5     19960.00              0.000        4.99           5
# 6     27491.67          16495.002        6.99           6
# 7     26182.00          15709.200        6.89           8
# 8     26093.67          15656.202        6.99           9
# 9     23792.34          14275.404        6.49          10
#
#                        Publisher   units sold
# 0        HarperCollins Publishers        7000
# 1        HarperCollins Publishers        6250
# 2  Amazon Digital Services,  Inc.        5500
# 3             Hachette Book Group        5500
# 4         Penguin Group (USA) LLC        4750
# 5  Amazon Digital Services,  Inc.        4000
# 6        HarperCollins Publishers        3933
# 7             Hachette Book Group        3800
# 8        HarperCollins Publishers        3733
# 9                Random House LLC        3666

# %%
df.isnull().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name               0
# Author                  0
# language_code          47
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.nunique()
# Out:
# index                  988
# Publishing Year        101
# Book Name              987
# Author                 669
# language_code            8
# Author_Rating            4
# Book_average_rating    133
# Book_ratings_count     983
# genre                    4
# gross sales            774
# publisher revenue      570
# sale price             143
# sales rank             818
# Publisher                9
# units sold             470
# dtype: int64

# %%
plt.hist(df['Publishing Year'])
plt.xlabel("Publishing Year")
plt.ylabel("Frequency")
plt.show()

# %%
df['genre'].value_counts().plot(kind = "bar")
plt.xlabel("Genre")
plt.ylabel("Number Of Books")
plt.title("Number of Books in Each Genre")
plt.show()

# %%
df.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# 1  Intermediate                 4.23              145267  genre fiction
# 2        Novice                 3.31              138669  genre fiction
# 3  Intermediate                 4.04              150898        fiction
# 4  Intermediate                 4.04              198283  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
# 1      12437.5             7462.5        1.99           2
# 2      47795.0            28677.0        8.69           3
# 3      41250.0            24750.0        7.50           3
# 4      37952.5            22771.5        7.99           4
#
#                        Publisher   units sold
# 0        HarperCollins Publishers        7000
# 1        HarperCollins Publishers        6250
# 2  Amazon Digital Services,  Inc.        5500
# 3             Hachette Book Group        5500
# 4         Penguin Group (USA) LLC        4750

# %%
df.groupby('Author')['Book_average_rating'].mean().sort_values(ascending = False)
# Out:
# Author
# Bill Watterson                  4.650000
# Bill Watterson, G.B. Trudeau    4.610000
# J.R.R. Tolkien                  4.590000
# George R.R. Martin              4.560000
# Sarah J. Maas                   4.526000
#                                   ...
# Chetan Bhagat                   3.273333
# Audrey Niffenegger              3.230000
# Herman Koch, Sam Garrett        3.220000
# P.D. James                      3.210000
# Sue Monk Kidd                   3.100000
# Name: Book_average_rating, Length: 669, dtype: float64

# %%
sns.boxplot(x = 'genre' , y = 'Book_ratings_count' , data = df)
plt.xlabel("Genre")
plt.ylabel("Book Ratings Count")
plt.title("Box Plot Of Book Ratings Count For Each Genre")
plt.show()

# %%
plt.scatter(df["sale price"] , df["units sold"])
plt.xlabel('Sale Price')
plt.ylabel('Units Sold')
plt.title("Scatter plot of sale price vs units sold")
plt.show()

# %%
language_counts = df['language_code'].value_counts()

# %%
plt.pie(language_counts , labels = language_counts.index ,startangle = 90 , autopct = "%1.1f%%")
plt.title("Language Distribution of books")
plt.show()

# %%
df.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# 1  Intermediate                 4.23              145267  genre fiction
# 2        Novice                 3.31              138669  genre fiction
# 3  Intermediate                 4.04              150898        fiction
# 4  Intermediate                 4.04              198283  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
# 1      12437.5             7462.5        1.99           2
# 2      47795.0            28677.0        8.69           3
# 3      41250.0            24750.0        7.50           3
# 4      37952.5            22771.5        7.99           4
#
#                        Publisher   units sold
# 0        HarperCollins Publishers        7000
# 1        HarperCollins Publishers        6250
# 2  Amazon Digital Services,  Inc.        5500
# 3             Hachette Book Group        5500
# 4         Penguin Group (USA) LLC        4750

# %%
df.groupby('Publisher ')['publisher revenue'].sum().sort_values(ascending  = False)
# Out:
# Publisher
# Penguin Group (USA) LLC                 191581.104
# Random House LLC                        174956.244
# Amazon Digital Services,  Inc.          141767.772
# HarperCollins Publishers                121769.814
# Hachette Book Group                     107410.968
# Simon and Schuster Digital Sales Inc     46858.206
# Macmillan                                31249.830
# HarperCollins Publishing                  2830.806
# HarperCollins Christian Publishing        2135.670
# Name: publisher revenue, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
df.groupby("Author_Rating")["Book_ratings_count"].mean().sort_values(ascending = False).max()
# Out:
# np.float64(101400.27256944444)

# %%
df.groupby("language_code").size().sort_values(ascending = False)
# Out:
# language_code
# eng      670
# en-US    226
# en-GB     29
# en-CA      7
# fre        4
# ara        2
# spa        2
# nl         1
# dtype: int64

# %%
df.groupby("Author_Rating")["Book_ratings_count"].var()
# Out:
# Author_Rating
# Excellent       4.419857e+08
# Famous          1.227555e+09
# Intermediate    1.170331e+09
# Novice          9.523157e+08
# Name: Book_ratings_count, dtype: float64

# %%
plt.scatter(df['Book_average_rating'] , df['Book_ratings_count'])
plt.xlabel("Book Average Rating")
plt.ylabel("Book Ratings Count")
plt.title("ScatterPlot of Book Average Ratings Vs Book Ratings Count")
plt.show()

# %%
total_gross_sales_by_author = df.groupby("Author")["gross sales"].sum()

# %%
total_gross_sales_by_author.sort_values(ascending = False).head(20).plot(kind = "bar")
plt.xlabel("Author")
plt.ylabel("Total Gross Sales")
plt.title("Total Gross Sales For Each Author")
plt.show()

# %%
sns.boxplot(x = "Author_Rating" , y = "units sold" , data = df)
plt.xlabel("Author Rating")
plt.ylabel("Units Sold")
plt.title("Box Plot of Units Sold for Each Rating")
plt.show()

# %%
df.groupby("Publishing Year")["units sold"].sum().plot(kind = 'line', marker = 'o')
plt.xlabel("Publishing Year")
plt.ylabel("Total Units Sold")
plt.title("Total Units Sold Over The Years")
plt.show()
